# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd
import numpy as np
import os
import kagglehub
# Download latest version
path = kagglehub.dataset_download("openfoodfacts/world-food-facts")
file_path = '/Users/alexanderfrankow/.cache/kagglehub/datasets/openfoodfacts/world-food-facts/versions/5/en.openfoodfacts.org.products.tsv'
food = pd.read_table(file_path, sep="\t",low_memory=False)
food.head()
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000016094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.head(5)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2  0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3  0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4  0000000016094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
print(f" the dataset has {food.shape[0]} observations")
# Out:
#  the dataset has 356027 observations

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
print(f" the dataset has {food.shape[1]} columns")
# Out:
#  the dataset has 163 columns

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
counter = 0 
for elem in food.columns:
    print(f"Name of column {counter} is: {elem}")
    counter += 1
# Out:
# Name of column 0 is: code
# Name of column 1 is: url
# Name of column 2 is: creator
# Name of column 3 is: created_t
# Name of column 4 is: created_datetime
# Name of column 5 is: last_modified_t
# Name of column 6 is: last_modified_datetime
# Name of column 7 is: product_name
# Name of column 8 is: generic_name
# Name of column 9 is: quantity
# Name of column 10 is: packaging
# Name of column 11 is: packaging_tags
# Name of column 12 is: brands
# Name of column 13 is: brands_tags
# Name of column 14 is: categories
# Name of column 15 is: categories_tags
# Name of column 16 is: categories_en
# Name of column 17 is: origins
# Name of column 18 is: origins_tags
# Name of column 19 is: manufacturing_places
# Name of column 20 is: manufacturing_places_tags
# Name of column 21 is: labels
# Name of column 22 is: labels_tags
# Name of column 23 is: labels_en
# Name of column 24 is: emb_codes
# Name of column 25 is: emb_codes_tags
# Name of column 26 is: first_packaging_code_geo
# ...

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
print(f" the name of the 105th column is: {food.iloc[:,104].name}")
# Out:
#  the name of the 105th column is: -glucose_100g

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food.iloc[:,104].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
print(food.index)
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
food["product_name"].iloc[18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'
